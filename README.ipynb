# %% [markdown]
# <h1 align='center'>✨ Welcome to the AMD AI Premier League (AAIPL)! ✨</h1>

# %% [markdown]
# <!-- <img src="./assets/aaipl.png"> -->
# <img src="./assets/AMDAAIPL.png">

# %% [markdown]
# ---
# ## Task
# You will be building:
# 1.  **A question agent** that will ask $N$ puzzle-based questions based on provided [topics](./assets/topics.json).
#     - Create your model in [question_model.py](./agents/question_model.py) (it will be called by [question_agent.py](./agents/question_agent.py) for evaluation)
#     - *Your question agent must output questions in the format specified in [sample_question.json](./assets/sample_question.json)*.
# 2. **An answer agent** that answers questions asked from a question agent.
#     -  Create your model in [answer_model.py](./agents/answer_model.py) (it will be called by [answer_agent.py](./agents/answer_agent.py) for evaluation)
#     -  *Your answer agent must output answers in the format specified in [sample_answer.json](./assets/sample_answer.json)*.
# ---

# %% [markdown]
# ## Instructions
#
# 1. How to initiate your workstation:
#     1. Go to **dev.amd-ai-academy.com**.
#     2. Type in the Team ID and Password from your printout.
#     3. Sign in.
# 1. Read through this README.ipynb for more details on the challenge.
#     - **Note:** If members of your team are working from the notebook simultaneously, please coordinate to ensure you do not overwrite each other's work.
# 1. You can **only** use the models provided in `/root/.cache/huggingface/hub`.
#     - These will be *read-only* - please **copy** a model you'd like to use into the `AAIPL/hf_models` folder. Here you can edit the model.
#     - If you attempt to change the models in the original folder, you will be **immediately disqualified**.
# 1. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.
# 1. Before the deadline, kindly ensure that you push your code to Github (except `hf_models`).
#     - You can use the [`git.sh`](./git.sh) script to easily push it.

# %% [markdown]
# ## 📚 Table of Contents:
# - 📝 [Task](#task)
# - ⚙️ [Instructions](#instructions)
# - 🏏 [Tournament Overview](#tournament-overview)
# - 📋 [Guidelines](#guidelines)
#     - [Format](#format-overview)
# - 🛠️ [Submission](#️what-you-will-submit)
# - ⚠️ [Restrictions](#restrictions)
# - 📂 [Directory & Files overview](#directory--files-overview)
# - 🎮 [Getting started](#getting-started)
#     - 🚀 [Env Setup](#env-setup)
#     - 🤔 [Q-Agent](#q-agent)
#         - ✅ [Basic format-checks for questions from Q-agent](#basic-format-checks-for-questions-from-q-agent)
#     - 🤖 [A-agent](#a-agent)
#         - ✅ [Basic format-checks for answers from A-agent](#basic-format-checks-for-answers-from-a-agent)
# - 🏅 [Evaluation](#evaluation)
#     - 📊 [Scoring Criteria](#scoring-criteria)
#     - 🧮 [Scoring Example](#scoring-example)
# - ⏱ [Time Limit](#time-limit)
# <!-- - 🏆 [LeaderBoard UI/UX](#leaderboard-uiux) -->

# %% [markdown]
# ## Tournament Overview
# <!-- 🏏  -->
# * All matches in this tournament will be **1v1** knockout format where two teams, Team-A vs Team-B, will compete with their Q-agent (question agent) and A-agent (answer agent). You can think of this as a cricket match or baseball game where teams will switch sides.
#   * Before the matchups begin, there will be an **elimination round** where we will test your A-Agent against a hidden set of questions. The teams' A-Agents that scores the highest on these seeding questions will move onto the elimination stage.
# * Like in cricket, each match has two innings:
#     -   1st inning:
#         *   $N$ Question from the Q-agent (Team-A) and their corresponding $N$ answers from the A-agent (Team-B).
#         *   Q-agent score (Team-A): Say, $40$
#         *   A-agent score (Team-B): $60$
#
#     -   2nd inning:
#         *   $N$ Question from the Q-agent (Team-B) and their respective $N$ responses from the A-agent (Team-A).
#         *   Q-agent score (Team-B): Say, $70$
#         *   A-agent score (Team-A): $30$
#     -   Final Score:
#         *   Team-A score $=$ 1st inning Q-agent score $+$ 2nd inning A-agent score $= 40 + 30 = 70$
#         *   Team-B score $=$ 1st inning A-agent score $+$ 2nd inning Q-agent score $= 60 + 70 = 130$
#     -   Winner: **Team-B** with a score of $130$.
#
# For more info on how scoring is done, refer to the [scoring criteria section](#scoring-criteria).

# %% [markdown]
# ## Guidelines
# <!-- 📋  -->
#
# ### Format
# We will only consider responses from the Q-agent and the A-agent which follow the below format.
#
# *Note*: While having an explanation/reasoning is a plus, not having them doesn't disqualify the question or answer being correct.
#
# #### Q-Agent
# Given a topic, the Q-agent should generate questions in the specified JSON format:
#
# ```json
# {
#     "topic": "<Topic of the Question>",
#     "question": "<full question text>",
#     "choices": [
#         "A) <choice A text>",
#         "B) <choice B text>",
#         "C) <choice C text>",
#         "D) <choice D text>"
#     ],
#     "answer": "<correct choice letter only>",
#     "explanation": "brief explanation within 100 words for why the answer is correct"
# }
# ```
#
# The **"Topic"**, **"Question"**, **"Choices"**, and **"Answer"** will be verified for correctness.
#
# #### A-Agent
# Given a Question and Choices, A-agent should produce answer in the format of:
#
# ```json
# {
#     "answer": "<correct choice letter only>",
#     "reasoning": "brief reasoning within 100 words for why the answer is correct"
# }
# ```
#
# The **"Answer"** key will be compared with **"Answer"** from the opponent's Q-agent.
#
# **<u>Note</u>**: *Once again, we will **only** consider those responses from the Q-agent and the A-agent which follow the above format.*

# %% [markdown]
# ## Submission
# <!-- 🛠️  -->
# You need to submit your code which should contain these main files:
# 1. All work must be within the `AAIPL` folder. Do NOT change the folder name.
# 1. No need to upload anything anywhere, we'll collect your agent code from your Jupyter Server at the end of the challenge.
#    1. The agents will be called by `python -m agents.question_agent` and `python -m agents.answer_agent`, respectively.
# 1. ENSURE model checkpoint(s) (e.g., `model.safetensors` or `.pt` or `.pth`) is (are) loading and expected files are getting generated from Q-agent and A-agent, when inference is done.
#    1. Outputs must be saved to `outputs/questions.json` and `outputs/answers.json`, respectively.
# 1. **<u>Note</u>: You are not required to generate any `.json` for us, we'll do that for you during evaluation setting a specific value to $N$.**
#
# You can test your submission by running the commands in the [Getting Started](#getting-started) section.
#
# <u><span style="color: blue">Note</span></u>: These files will be checked for any hardcoding, RAG, or other unfair practices.<br>
# <u><span style="color: red">Remarks / Caution</span></u>: A-agent is equally important as Q-agent. So, please do focus on both.

# %% [markdown]
# ## Restrictions
# <!-- ⚠️ -->
#
# 1.  **<span style="color: red">NO</span> LAST Minute Submission**: The submission deadline is strict. Any changes to your code after the deadline may disqualify your submission.
# 1.  RAG (Retrieval Augmented Generation) techniques are not allowed.
# 1.  Adversarial approaches will lead to disqualification, e.g. making A-agents hallucinate.
# 1.  Usage of models other than what was provided will lead to disqualification.
# 1.  Only English language is allowed for both Q-agent and A-agent.
# 1.  Strictly stay within the `max_tokens` limits specified in `agen.yaml` & `qgen.yaml`. Other parameters can be changed.
# 1.  Questions must pertain to the topics listed in `topics.json`.
# 1.  Each question should be generated under `13 secs`. Questions exceeding this limit will not be considered.
# 1.  Each answer should be generated under `9 secs`. Answers exceeding this limit will not be considered.
#
# Feel free to reach out in the Discord channel for any clarifications or questions!

# %% [markdown]
# ## Directory & Files overview
# <!-- 📂  -->
#
# ```plaintext
# .
# ├── agents
# │   ├── question_model.py
# │   ├── question_model_llama.py (example code using Unsloth Llama)
# │   ├── question_agent.py
# │   ├── answer_model.py
# │   ├── answer_model_llama.py (example code using Unsloth Llama)
# │   └── answer_agent.py
# ├── assets
# │   ├── topics_example.json # example questions w.r.t each topic
# │   ├── topics.json # Topics on which we require to generate questions
# │   ├── sample_question.json # File specifying expected format of questions generated
# │   └── sample_answer.json # Expected format of answers generated
# ├── utils
# │   └── build_prompt.py # prompt-tuning scripts
# ├── README.ipynb
# ├── tutorial.ipynb # Synthetic Data Generation and Unsloth Tutorial
# ├── tutorial_config.yaml # Config file for tutorial
# ├── qgen.yaml # Generation specific parameters for Q-agent
# └── agen.yaml # Generation specific parameters for A-agent
# ```

# %% [markdown]
# ## Getting started
# <!-- 🎮  -->
# Let's get started with running the Q-agent and A-agent framework.
#
# ### Environment Setup
# <!-- 🚀 -->

# %%
# Import basic packages
import json
from typing import Dict, Any, List

# %% [markdown]
# ### Q-Agent
# <!-- 🤔 -->
# You will update the model in `question_model.py`, which will be invoked by `question_agent.py`. In the provided skeleton, we have used the base Qwen3-4B model for Q-Agent but you should experiment with other models and techniques. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.
#
# Generated questions must pertain to the topics mentioned in `topics.json` file. Additional topics will be added for the tournament finals.
#
# __Topics:__
# 1.  `Logical Reasoning`: Syllogisms
# 2.  `Puzzles`: Seating Arrangements (Linear, Circular)
# 3.  `Blood Relations and Family Tree`: Puzzles involving generations and family tree logic
# 4.  `Alphanumeric Series`: Mixed series questions
#
# Sample questions and answers are available in the [assets folder](./assets).

# %%
# Run the following code to generate questions.
# For demo purpose, we have used the base Qwen3-4B model for Q-Agent. Participants are expected to improve upon this
# !python -m agents.question_agent \
    --output_file "outputs/questions.json" \
    --num_questions 50 \
    --verbose
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# #### Unsloth: `hf_xet==1.1.10` and `ipykernel>6.30.1` breaks progress bars. Disabling for now in XET.
# #### Unsloth: To re-enable progress bars, please downgrade to `ipykernel==6.30.1` or wait for a fix to
# https://github.com/huggingface/xet-core/issues/526
# INFO 02-15 08:33:41 [__init__.py:225] Automatically detected platform rocm.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: AMD currently is not stable with 4bit bitsandbytes. Disabling for now.
# ==((====))==  Unsloth 2025.10.9: Fast Qwen2 patching. Transformers: 4.56.2. vLLM: 0.11.1rc3.dev39+gf417746ad.rocm700.
#    \\   /|    . Num GPUs = 1. Max memory: 255.688 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0a0+git1c57644. ROCm Toolkit: 7.0.51831-a3e329ad8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards: 100%|██████████████████| 8/8 [00:19<00:00,  2.40s/it]
# Loaded successfully ✅
# STEPS: 100%|████████████████████████████████████| 10/10 [00:55<00:00,  5.54s/it]
# Generated 50 questions!
# {"topic":"Family tree logic","question":"Rajesh points to a man and says, \"He is the only son of my mother’s sister.\" How is the man related to Rajesh?","choices":["A) Uncle","B) Brother","C) Cousin","D) Nephew"],"answer":"C","explanation":"The only son of Rajesh's mother's sister is his cousin."}
# {"topic":"Family tree logic","question":"Rahul points to a man and says, \"He is the brother of my mother.\" How is the man related to Rahul?","choices":["A) A) Uncle","B) B) Father","C) C) Cousin","D) D) Brother"],"answer":"A","explanation":"The brother of Rahul's mother is Rahul's uncle."}
# {"topic":"Syllogisms","question":"Statement I: All cats are dogs; Statement II: No dog is a bird; Statement III: All birds are fish; Conclusions I: No cat is a fish; Conclusion II: Some fish are cats","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"A","explanation":"Since all cats are dogs and no dog is a bird, then no cat can be a fish. The second conclusion contradicts this."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a circular arrangement, 5 friends - Alice, Bob, Carol, Dave, Eve - sit around a table. If Alice sits next to Bob and Dave sits opposite Carol, who is sitting between Alice and Dave?","choices":["A) Bob","B) Carol","C) Eve","D) Bob"],"answer":"D","explanation":"Alice sits next to Bob, and Dave sits opposite Carol. This means Eve must sit between Alice and Dave."}
# {"topic":"Syllogisms","question":"Statement I: All books are pens
# Statement II: Some pens are pencils
# Statement III: All pencils are erasers
# Conclusions I: Some erasers are books
# Conclusion II: Some pens are erasers","choices":["A) A) If only conclusion I follow","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"Pens are connected to both books and erasers but no direct link from books to erasers exists."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, and E sit in a row facing north. A sits next to B but not next to C. D is between B and E. Who is sitting second to the right of the person sitting third from the left?","choices":["A) A) C","B) B) D","C) C) B","D) D) E"],"answer":"C","explanation":"The seating order is C-A-B-D-E. Third from the left is B. Second to B's right is D."}
# {"topic":"Family tree logic","question":"Rahul points to a man and says, \u201cHe is the brother of my mother\u2019s only daughter.\u201d How is the man related to Rahul?","choices":["A) A) Uncle","B) B) Brother","C) C) Cousin","D) D) Father"],"answer":"B","explanation":"Rahul's mother's only daughter is Rahul himself. Hence, the man who is the brother of Rahul's mother is Rahul's Brother."}
# {"topic":"Syllogisms","question":"Statement I: Some cats are dogs; Statement II: All dogs are mammals; Conclusion I: Some mammals are cats; Conclusion II: Some cats are mammals","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"All dogs being mammals ensures some cats are mammals but not necessarily that some mammals are cats."}
# {"topic":"Syllogisms","question":"Statement I: Some dogs are cats
# Statement II: All cats are birds
# Statement III: Some birds are fish
# Conclusions I: Some fish are cats
# Conclusion II: Some birds are dogs","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"D","explanation":"There is no definitive link proving fish are cats or birds are dogs based on given statements."}
# {"topic":"Syllogisms","question":"Statement I: Some cats are dogs; Statement II: All dogs are birds; Statement III: Some birds are fish. Conclusions I: Some fish are dogs; Conclusion II: Some birds are cats","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"While all dogs being birds means some birds can be cats, no direct fish-dog link exists."}
# {"topic":"Syllogisms","question":"Statement I: Some cats are dogs; Statement II: All dogs are animals; Conclusion I: Some animals are cats; Conclusion II: Some dogs are cats","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusions I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"C","explanation":"Some cats being dogs allows for some animals to be cats and some dogs to be cats."}
# {"topic":"Family tree logic","question":"Rajesh introduces his sister-in-law as the wife of his brother's only child. How is Rajesh's sister-in-law related to him?","choices":["A) A) Sister-in-law","B) B) Wife","C) C) Niece","D) D) Cousin"],"answer":"C","explanation":"Rajesh's sister-in-law is married to his brother's only child, making her the niece of Rajesh."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB2, CD4, EF6, GH8, ___","choices":["A) A) IJ10","B) B) HI10","C) C) JK9","D) D) IL11"],"answer":"B","explanation":"First and second letters follow alphabetical order while numbers increase by 2. Hence HI10."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a linear seating arrangement, 5 friends - Alice, Bob, Carol, Dave, and Eve - sit facing North. To their immediate South, another set of 5 friends - Fred, Gina, Henry, Ivy, and Jack - face North. If Alice sits opposite Gina, who is to the right of Henry, and Bob is opposite Ivy, who is between Gina and Jack, and Dave is opposite Fred, who is at one end, then after swapping places between Alice and Fred, Bob and Ivy, and Dave and Gina, who is now sitting second to the right of the person opposite the second person to the right of Fred?","choices":["A) A) Eve","B) B) Carol","C) C) Bob","D) D) Dave"],"answer":"C","explanation":"Alice swaps with Fred, Bob with Ivy, Dave with Gina. New positions: Men: Fred-Bob-Dave-Gina-Eve; Women: Alice-Ivy-Carol-Henry-Jack. Fred's second right is Ivy; opposite Ivy is Bob."}
# {"topic":"Family tree logic","question":"Rajesh says, \"He is the brother of my mother’s only sibling.\" How is the man related to Rajesh?","choices":["A) A) Uncle","B) B) Cousin","C) C) Nephew","D) D) Brother"],"answer":"B","explanation":"Rajesh's mother has an only sibling who is his aunt. The brother of Rajesh's aunt is Rajesh's cousin."}
# {"topic":"Syllogisms","question":"Statement I: Some cats are dogs; Statement II: All dogs are mammals; Statement III: Some mammals are elephants; Conclusions I: Some mammals are cats; Conclusion II: Some elephants are dogs","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"A","explanation":"Some cats are dogs implies some mammals can be cats. There's no direct link proving elephants are dogs."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB1, CD2, EF3, GH4, _____","choices":["A)IJ5","B)HI5","C)IF5","D)IH5"],"answer":"A","explanation":"The pattern involves alternating between increasing letters AB, CD, EF, GH and increasing numbers 1, 2, 3, 4. Thus, the next term should be IJ5."}
# {"topic":"Family tree logic","question":"Rajesh says, \"He is the son of my mother's only sibling.\" How is Rajesh related to the boy?","choices":["A) A) Nephew","B) B) Uncle","C) C) Cousin","D) D) Brother"],"answer":"B","explanation":"Rajesh's mother's only sibling is his aunt. The son of Rajesh's aunt is his nephew. Hence, Rajesh is the boy's Uncle."}
# {"topic":"Syllogisms","question":"Statement I: All books are pens
# Statement II: Some pens are pencils
# Statement III: All pencils are erasers
# Conclusions I: Some erasers are books
# Conclusion II: Some pens are erasers","choices":["A) A) If only conclusion I follow","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"Some pens are erasers as stated; no direct link shows some erasers are books."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, E sit in a row. B sits next to neither A nor D. C sits next to A but not next to E. Who sits second from the left?","choices":["A) A) A","B) B) C","C) C) D","D) D) E"],"answer":"A","explanation":"C sits next to A but not E, placing A and C together. B cannot sit next to A or D, so B sits next to C. Thus, the order is D-C-B-A-E, making A second from the left."}
# {"topic":"Family tree logic","question":"Raj says, \u201cHe is the brother of my mother\u2019s only daughter.\u201d How is Raj related to the person he is talking about?","choices":["A) A) Brother","B) B) Uncle","C) C) Son","D) D) Nephew"],"answer":"D","explanation":"Raj's mother's only daughter is Raj himself. Therefore, the person referred to as the brother of Raj's mother's only daughter is Raj's brother, making Raj the Nephew of that person."}
# {"topic":"Mixed Series (Alphanumeric)","question":"2A3, 4B6, 6C9, 8D12, _____","choices":["A) A) 10E15","B) B) 10F14","C) C) 9E15","D) D) 10E16"],"answer":"A","explanation":"Each term increases by 2 in the numerical part and follows an alphabetical sequence for the letter. The numerical part is multiplied by the position of the term in the series (1*2=2, 2*2=4, 3*2=6, 4*2=8, 5*2=10)."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB_2, CD_4, EF_6, GH_8, _____","choices":["A) A) IJ_10","B) B) HI_10","C) C) IJ_9","D) D) HI_9"],"answer":"A","explanation":"The first two letters form an alternating pattern of increasing alphabet pairs AB, CD, EF, GH followed by IJ. The numbers increase by 2 each time: 2, 4, 6, 8, 10."}
# {"topic":"Syllogisms","question":"Statement I: Some cats are dogs Statement II: All dogs are animals Conclusion I: Some animals are cats Conclusion II: Some dogs are cats","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"While all dogs being animals means some animals could be dogs, there's no direct link proving some animals are cats or that some dogs are specifically cats."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, and E sit in a row facing north. B sits third from the left end. C is immediately to the right of B. D is to the immediate left of A. E is not next to B. If they rearrange such that D moves two places to the right, who is now second from the right?","choices":["A) A) B","B) B) C","C) C) D","D) D) E"],"answer":"D","explanation":"Initial arrangement: A-D-C-B-E. After moving D two places right, the new order is A-B-D-C-E. Second from the right is D."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB_1, BC_2, CD_3, DE_4, EF_5, FG_6, GH_7, HI_8, IJ_9, JK_10, KL_11, LM_12, MN_13, NO_14, OP_15, PQ_16, QR_17, RS_18, ST_19, TU_20, UV_21, VW_22, WX_23, XY_24, YZ_25, __","choices":["A) A) ZY_26","B) B) XW_26","C) C) YX_26","D) D) ZX_26"],"answer":"C","explanation":"The pattern involves consecutive alphabets where the first two letters move forward by one letter each step and the numeric part increments by 1. Reversing the last pair yields YX_26."}
# {"topic":"Syllogisms","question":"Statement I: Some birds are mammals
# Statement II: All mammals are reptiles
# Statement III: Some reptiles are amphibians
# Conclusion I: Some amphibians are mammals
# Conclusion II: Some reptiles are birds","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"D","explanation":"Mammals are reptiles does not imply amphibians are mammals; reptiles being mammals or birds is not directly supported."}
# {"topic":"Syllogisms","question":"Statement I: Some dogs are cats; Statement II: All cats are birds; Statement III: Some birds are fish. Conclusions I: Some fish are cats; Conclusion II: Some birds are dogs","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"D","explanation":"No direct link between fish and cats exists. Birds and dogs relationship is not certain from given statements."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a circular table seating, five friends A, B, C, D, and E sit clockwise in that order. If A and C swap places, then who will be seated between B and D?","choices":["A) A) A","B) B) C","C) C) E","D) D) D"],"answer":"B","explanation":"After A and C swap, the order becomes C-B-D-E-A. Thus, C sits between B and D."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, and E are sitting in a row facing north. A is between B and C. D is not at either end and sits to the right of C. If E is to the immediate left of D, who is second to the right of the person sitting immediately to the left of C?","choices":["A) A) B","B) B) C","C) C) E","D) D) D"],"answer":"D","explanation":"Arrangement: B-A-C-E-D. Left of C is A. Second to the right of A is D."}
# {"topic":"Family tree logic","question":"Raj points to a man and says, \u201cHe is the only son of my father\u2019s only daughter.\u201d How is the man related to Raj?","choices":["A) A) Brother","B) B) Nephew","C) C) Son","D) D) Cousin"],"answer":"A","explanation":"The only daughter of Raj\u2019s father is Raj\u2019s sister. The only son of Raj\u2019s sister is Raj\u2019s brother."}
# {"topic":"Family tree logic","question":"Rahul states, \"He is the son of my father's only sister.\" How is the person related to Rahul?","choices":["A) Son","B) Nephew","C) Cousin","D) Brother"],"answer":"C","explanation":"My father's only sister is Rahul's aunt. Her son is therefore Rahul's cousin."}
# {"topic":"Family tree logic","question":"Rajesh says, \u0022He is the son of my father\u0027s only sibling.\u0022 How is Rajesh related to the boy?","choices":["A) A) Brother","B) B) Cousin","C) C) Uncle","D) D) Nephew"],"answer":"B","explanation":"Rajesh's father's only sibling is his uncle or aunt. The son of an uncle/aunt is Rajesh's cousin."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a linear arrangement, five friends A, B, C, D, E sit facing North while F, G, H, I, J sit facing South. If B is opposite F, C is to the immediate right of B, G is immediately to the left of F, D is opposite H, and J is at one end facing South. After B and H swap places, who is second to the right of the person opposite J?","choices":["A) A) C","B) B) B","C) C) D","D) D) A"],"answer":"B","explanation":"B was initially opposite F but swaps with H. Thus, H faces North opposite F. J is at one end, so its opposite is A. Second to the right of A is B."}
# {"topic":"Family tree logic","question":"Rajesh says, \"He is the brother of my father’s only daughter.\" How is the man related to Rajesh?","choices":["A) A) Uncle","B) B) Brother","C) C) Cousin","D) D) Nephew"],"answer":"B","explanation":"My father's only daughter is Rajesh's sister. The brother of Rajesh's sister is Rajesh himself; thus, the man is Rajesh's Brother."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB1, CD2, EF3, GH4, _____","choices":["A) A) IJ5","B) B) HI5","C) C) IH5","D) D) JK5"],"answer":"C","explanation":"The first two letters follow the pattern of alternating between increasing by one letter in the alphabet and skipping one letter. The numbers increase sequentially by 1. Hence IH5."}
# {"topic":"Family tree logic","question":"Rajesh says, \"He is the son of my wife's only sibling.\" How is Rajesh related to the boy?","choices":["A) A) Uncle","B) B) Father","C) C) Brother-in-law","D) D) Cousin"],"answer":"C","explanation":"Rajesh's wife's only sibling is her sister or brother. If it's her sister, then the son would be Rajesh's brother-in-law. If it's her brother, he wouldn't have a son. Thus, the correct relation is Brother-in-law."}
# {"topic":"Family tree logic","question":"Rajesh points to a man and says, \u0022He is the son of my father\u0027s only daughter.\u0022 How is Rajesh related to the man?","choices":["A) A) Uncle","B) B) Father","C) C) Brother","D) D) Nephew"],"answer":"D","explanation":"Rajesh\u0027s father\u0027s only daughter is Rajesh\u0027s sister. The son of Rajesh\u0027s sister is Rajesh\u0027s nephew."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a linear seating arrangement, six friends A, B, C, D, E, and F are sitting in a row facing North. B is third from the left, A is to the immediate left of B, C is between A and D, and E is to the immediate right of D. Who is second to the right of F if F is at one end of the row?","choices":["A) A) A","B) B) C","C) C) E","D) D) D"],"answer":"C","explanation":"Given positions: B is 3rd from left, A immediately left of B, C between A and D, E immediately right of D. Thus, order is F-C-A-B-D-E. Second to right of F is C."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a linear seating arrangement, six friends A, B, C, D, E, F sit facing North. B sits second to the right of A. D is not an immediate neighbor of B. C sits third to the left of E. F does not sit next to D. Who sits between A and E?","choices":["A) A) B","B) B) C","C) C) D","D) D) F"],"answer":"D","explanation":"A sits at one end, B second to A's right. C third left of E means E sits fourth from A's right. F not next to D and D not next to B leaves F between A and E."}
# {"topic":"Family tree logic","question":"Rajesh points to a man and says, \"He is the brother of my mother's only daughter.\" How is the man related to Rajesh?","choices":["A) A) Brother","B) B) Uncle","C) C) Cousin","D) D) Nephew"],"answer":"B","explanation":"The brother of Rajesh's mother's only daughter is Rajesh's uncle."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, E sit in a row facing north. B sits next to neither A nor C. D sits next to both B and E. Who is sitting second to the right of the person sitting between B and E?","choices":["A) A) A","B) B) C","C) C) D","D) D) E"],"answer":"C","explanation":"Arrangement is A-D-B-E-C. Between B and E is D. Second to the right of D is C."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB2, CD4, EF6, GH8, ___","choices":["A) A) IJ10","B) B) HI10","C) C) IJ9","D) D) HI9"],"answer":"A","explanation":"The first and second letters follow alphabetical order in pairs. The numbers double every step: 2, 4, 6, 8, 10."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB_2, CD_4, EF_6, GH_8, _____","choices":["A)IJ_10","B)JI_9","C)HI_10","D)IH_9"],"answer":"A","explanation":"The first two letters follow the pattern of alternating pairs of letters in the alphabet. The number sequence increases by 2 each time: 2, 4, 6, 8, 10."}
# {"topic":"Syllogisms","question":"Statement I: All dogs are cats
# Statement II: Some cats are birds
# Statement III: All birds are fish
# Conclusions I: Some fish are cats
# Conclusion II: All dogs are fish","choices":["A) A) If only conclusion I follow","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"D","explanation":"Some cats being birds means some fish are cats. Dogs being cats does not ensure they are fish."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, and E are sitting in a row facing North. B is between A and C, and D is not next to E. If A and D swap places, who will be sitting second to the right of the person originally next to B?","choices":["A) A) A","B) B) C","C) C) D","D) D) E"],"answer":"B","explanation":"Initially, the seating order can be A-B-C-D-E or E-D-C-B-A based on conditions. Swapping A and D gives D-B-C-A-E. Originally, B was next to A and C. Second to the right of C is D but since A and D swapped, it's now C."}
# {"topic":"Family tree logic","question":"Rahul says, \"He is the brother of my father's only daughter.\" How is Rahul related to the person he is referring to?","choices":["A) A) Uncle","B) B) Brother","C) C) Cousin","D) D) Nephew"],"answer":"B","explanation":"Rahul's father's only daughter is Rahul's sister. The brother of Rahul's sister is Rahul himself."}
# {"topic":"Family tree logic","question":"Raj points to a man and says, \"He is the brother of my mother's only daughter.\" How is the man related to Raj?","choices":["A) A) Uncle","B) B) Father","C) C) Cousin","D) D) Brother"],"answer":"D","explanation":"Raj's mother's only daughter would be Raj himself. Hence, the man who is the brother of Raj's mother is Raj's Brother."}
# {"topic":"Mixed Series (Alphanumeric)","question":"2A3, 4D5, 6G7, 8J9, ___","choices":["A) A) 10M11","B) B) 10L11","C) C) 10K11","D) D) 10N11"],"answer":"A","explanation":"The number sequence increases by 2; the letter sequence follows every third letter in the alphabet."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB1, CD2, EF3, GH4, _____","choices":["A) A) IJ5","B) B) HI5","C) C) IH5","D) D) JK5"],"answer":"C","explanation":"The pattern involves alternating the first and second letters while increasing the numeric value by 1 each time. Thus, the correct sequence is IH5."}
#
# ==================================================
#
#
# Time taken per batch generation: [17.270753860473633, 3.2493932247161865, 5.661256313323975, 3.5745418071746826, 3.922755002975464, 5.393909692764282, 4.426400661468506, 4.376140594482422, 3.2356324195861816, 4.274234771728516]
# Tokens generated per batch: [680, 645, 1170, 715, 790, 1110, 900, 890, 640, 865]
# Total Time Taken: 55.385 seconds; Total Tokens: 8405; TGPS: 151.756 seconds
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Saved to outputs/questions.json!

# %% [markdown]
# #### Basic format-checks for questions from Q-agent
#
# Generated questions must follow the [format instructions](#format-overview). All questions generated from the Q-agent will be filtered and validated before being sent to the opponent's A-agent. We generate two version of questions, one is the raw, unfiltered one `questions.json` and the other is `filtered_questions.json` after passing through the below example filter. The full filtering and validation process is part of the judging system and is not demonstrated here.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-4B", padding_side='left')

def count_tokens_q(text: str) -> int:
    """Count the number of tokens using Qwen3-4B tokenizer"""
    return len(tokenizer.encode(text, add_special_tokens=False))

def filter_questions(questions: List[str|Dict[str, str|Any]]) -> List[Dict[str, str|Any]]:
    def basic_checks(q2: Dict[str, str])->bool:
        # check required keys
        required_keys = ['topic', 'question', 'choices', 'answer']
        if all((key in q2) for key in required_keys):
            # check choices format
            checks = all(isinstance(choice, str) and len(choice) > 2 and choice[0].upper() in 'ABCD' for choice in q2['choices'])
            if isinstance(q2['choices'], list) and len(q2['choices']) == 4 and checks:
                # check answer format
                # Check token length
                check_len = sum(count_tokens_q(q2[k]) for k in ['question', 'answer'])
                check_len += sum(count_tokens_q(choice) for choice in q2['choices']) - 15
                if check_len < 130:
                    if check_len + count_tokens_q(q2.get('explanation', 'None')) <= 1024:
                        # Extra Checks: (PLUS checks) len(q2['answer']) == 1 and q2['answer'].upper() in 'ABCD':
                        if isinstance(q2['answer'], str):
                            return True
        return False
    correct_format_question = []
    for i, q in enumerate(questions):
        if isinstance(q, dict):
            if basic_checks(q):
                correct_format_question.append(q)
        elif isinstance(q, str):
            try:
                q1 = json.loads(q)
                if basic_checks(q1):
                    correct_format_question.append(q1)
            except json.JSONDecodeError:
                # If JSON decoding fails, skip this answer
                print(f"Skipping invalid JSON at index {i}: {q}")
                continue
        else:
            continue
    if len(correct_format_question) >= 0.5 * len(questions):
        return correct_format_question
    return list()

# %%
with open("outputs/questions.json", "r") as f:
    questions = json.load(f)

filtered_questions = filter_questions(questions)

with open("outputs/filtered_questions.json", "w") as f:
    json.dump(filtered_questions, f, indent=4)

print(f"Number of questions: {len(questions)}")
print(f"Number of filtered questions: {len(filtered_questions)}")

# %% [markdown]
# ### A-agent
# <!-- 🤖  -->
# You will update the model in `answer_model.py`, which will be invoked by `answer_agent.py`. In the provided skeleton, we have again used the base Qwen3-4B model for A-Agent but you should experiment with other models and techniques. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.

# %%
# Same instructions apply for the answer agent.
# For demo purpose, we have used the base Qwen3-4B model for A-agent. Participants are expected to improve upon this.
# !python -m agents.answer_agent \
    --input_file "outputs/filtered_questions.json" \
    --output_file "outputs/answers.json" \
    --verbose
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# #### Unsloth: `hf_xet==1.1.10` and `ipykernel>6.30.1` breaks progress bars. Disabling for now in XET.
# #### Unsloth: To re-enable progress bars, please downgrade to `ipykernel==6.30.1` or wait for a fix to
# https://github.com/huggingface/xet-core/issues/526
# INFO 02-15 08:44:02 [__init__.py:225] Automatically detected platform rocm.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: AMD currently is not stable with 4bit bitsandbytes. Disabling for now.
# ==((====))==  Unsloth 2025.10.9: Fast Qwen2 patching. Transformers: 4.56.2. vLLM: 0.11.1rc3.dev39+gf417746ad.rocm700.
#    \\   /|    . Num GPUs = 1. Max memory: 255.688 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0a0+git1c57644. ROCm Toolkit: 7.0.51831-a3e329ad8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards: 100%|██████████████████| 8/8 [00:20<00:00,  2.61s/it]
# Unsloth 2025.10.9 patched 48 layers with 48 QKV layers, 48 O layers and 48 MLP layers.
# STEPS:  10%|███▍                              | 1/10 [00:16<02:32, 16.96s/batch]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# STEPS:  20%|██████▊                           | 2/10 [00:21<01:17,  9.67s/batch]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# STEPS:  30%|██████████▏                       | 3/10 [00:26<00:53,  7.70s/batch]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.

# %% [markdown]
# #### Basic format-checks for answers from A-agent
# Generated answers must follow the [format instructions](#format-overview). The following filter is added into the `answer_agent.py`. Similar to before, two versions are saved, `answers.json` and `filtered_answers.json`. The latter is used for evaluation.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-4B", padding_side='left')

def count_tokens_a(text: str) -> int:
    """Count the number of tokens in the text using the agent's tokenizer"""
    return len(tokenizer.encode(text, add_special_tokens=False))

def filter_answers(ans: List[str|Dict[str, str]]) -> List[Dict[str, str]]:
    r"""Filter answers to ensure they are in the correct format"""
    def basic_checks(a1: Dict[str, str])->bool:
        # check required keys
        required_keys = ['answer']
        if all((key in a1) and isinstance(a1[key], str) for key in required_keys):
            if len(a1['answer']) == 1 and (a1['answer'] not in 'ABCDabcd'):
                    return False
            check_len = count_tokens_a(a1['answer'])
            if check_len < 50:
                check_len += count_tokens_a(a1.get('reasoning', 'None'))
                if check_len < 512:
                    # check answer format - EXTRA checks
                    # if len(a1['answer']) == 1 and a1['answer'].upper() in 'ABCD':
                    return True
        return False

    filtered_answers = []
    for i, a in enumerate(ans):
        if isinstance(a, dict):
            if basic_checks(a):
                filtered_answers.append(a)
            else:
                filtered_answers.append(None)
        elif isinstance(a, str):
            # Basic checks: at least with correct JSON format
            try:
                a1 = json.loads(a)
                if basic_checks(a1):
                    filtered_answers.append(a1)
                else:
                    filtered_answers.append(None)
            except json.JSONDecodeError:
                # If JSON decoding fails, skip this answer
                print(f"Skipping invalid JSON at index {i}: {a}")
                filtered_answers.append(None)
                continue
        else:
            # If the answer is neither a dict nor a str, skip it
            print(f"Skipping unsupported type at index {i}: {type(a)}")
            filtered_answers.append(None)
    return filtered_answers

# %%
with open("outputs/answers.json", "r") as f:
    answers = json.load(f)
filtered_answers = filter_answers(answers)


print(f"Number of answers: {len(answers)}")
print(f"Number of filtered answers: {len(filtered_answers)}")

# %% [markdown]
# ## Evaluation
# <!-- 🏅  -->

# %% [markdown]
# ### Scoring Criteria
#
# <!-- 📊  -->
#
# Scores are assigned based on: out of $N$ questions from Q-agent, how many an A-agent can answer and vice-versa. *No negative marking for wrong answers.*
#
# $$\text{A-agent Score} = \dfrac{\#\ \text{of questions correctly answered with expected format}}{N}\times 100$$
# $$\text{Q-agent Score} = \dfrac{\#\ \text{of questions incorrectly answered by A-agent}}{N}\times 100$$
#
#
# $N$ denotes the number of filtered / format-correct questions. **Teams whose Q-agent fails to generate at least $50\%$ of `num_questions` (where `num_questions` ranges from $2$ to $1000+$) of the questions correctly (as per [format-checking](#format-overview)) will be automatically disqualified.**<br>
#
# In case of **TIE**, closed benchmark questions will be used to evaluate the answer agents (A-agent) and rank the teams accordingly.

# %% [markdown]
# ### Scoring Example

# %%
# calculate scores...
N = len(filtered_questions)
assert N == len(filtered_answers), "Number of questions and answers must match."
num_correct_answers = len([1 for q,a in zip(filtered_questions, filtered_answers) if a is not None and q['answer'] == a['answer']])

# Here the answer may be correct, but since q['answer'] is not an option letter is not there, we face problems
# Below shown is one way of simple string parsing
num_correct_answers = len([1 for q,a in zip(filtered_questions, filtered_answers) if a is not None and q['answer'][0] == a['answer']])

a_score = num_correct_answers*100/(N+1e-9)
q_score = (N-num_correct_answers)*100/(N+1e-9)
# Announce the scores
print(f"Number of questions: {N}")
print(f"Number of correct answers: {num_correct_answers}")
print("Scores:")
print(f"Team B: A-agent score: {a_score:.2f}")
print(f"Team A: Q-agent score: {q_score:.2f}")
print(f"Innings 1 winner: {'Team A' if q_score > a_score else 'Team B' if q_score < a_score else 'Draw'}")
