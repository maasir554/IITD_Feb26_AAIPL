# %% [markdown]
# <h1 align='center'>✨ Welcome to the AMD AI Premier League (AAIPL)! ✨</h1>

# %% [markdown]
# <!-- <img src="./assets/aaipl.png"> -->
# <img src="./assets/AMDAAIPL.png">

# %% [markdown]
# ---
# ## Task
# You will be building:
# 1.  **A question agent** that will ask $N$ puzzle-based questions based on provided [topics](./assets/topics.json).
#     - Create your model in [question_model.py](./agents/question_model.py) (it will be called by [question_agent.py](./agents/question_agent.py) for evaluation)
#     - *Your question agent must output questions in the format specified in [sample_question.json](./assets/sample_question.json)*.
# 2. **An answer agent** that answers questions asked from a question agent.
#     -  Create your model in [answer_model.py](./agents/answer_model.py) (it will be called by [answer_agent.py](./agents/answer_agent.py) for evaluation)
#     -  *Your answer agent must output answers in the format specified in [sample_answer.json](./assets/sample_answer.json)*.
# ---

# %% [markdown]
# ## Instructions
#
# 1. How to initiate your workstation:
#     1. Go to **dev.amd-ai-academy.com**.
#     2. Type in the Team ID and Password from your printout.
#     3. Sign in.
# 1. Read through this README.ipynb for more details on the challenge.
#     - **Note:** If members of your team are working from the notebook simultaneously, please coordinate to ensure you do not overwrite each other's work.
# 1. You can **only** use the models provided in `/root/.cache/huggingface/hub`.
#     - These will be *read-only* - please **copy** a model you'd like to use into the `AAIPL/hf_models` folder. Here you can edit the model.
#     - If you attempt to change the models in the original folder, you will be **immediately disqualified**.
# 1. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.
# 1. Before the deadline, kindly ensure that you push your code to Github (except `hf_models`).
#     - You can use the [`git.sh`](./git.sh) script to easily push it.

# %% [markdown]
# ## 📚 Table of Contents:
# - 📝 [Task](#task)
# - ⚙️ [Instructions](#instructions)
# - 🏏 [Tournament Overview](#tournament-overview)
# - 📋 [Guidelines](#guidelines)
#     - [Format](#format-overview)
# - 🛠️ [Submission](#️what-you-will-submit)
# - ⚠️ [Restrictions](#restrictions)
# - 📂 [Directory & Files overview](#directory--files-overview)
# - 🎮 [Getting started](#getting-started)
#     - 🚀 [Env Setup](#env-setup)
#     - 🤔 [Q-Agent](#q-agent)
#         - ✅ [Basic format-checks for questions from Q-agent](#basic-format-checks-for-questions-from-q-agent)
#     - 🤖 [A-agent](#a-agent)
#         - ✅ [Basic format-checks for answers from A-agent](#basic-format-checks-for-answers-from-a-agent)
# - 🏅 [Evaluation](#evaluation)
#     - 📊 [Scoring Criteria](#scoring-criteria)
#     - 🧮 [Scoring Example](#scoring-example)
# - ⏱ [Time Limit](#time-limit)
# <!-- - 🏆 [LeaderBoard UI/UX](#leaderboard-uiux) -->

# %% [markdown]
# ## Tournament Overview
# <!-- 🏏  -->
# * All matches in this tournament will be **1v1** knockout format where two teams, Team-A vs Team-B, will compete with their Q-agent (question agent) and A-agent (answer agent). You can think of this as a cricket match or baseball game where teams will switch sides.
#   * Before the matchups begin, there will be an **elimination round** where we will test your A-Agent against a hidden set of questions. The teams' A-Agents that scores the highest on these seeding questions will move onto the elimination stage.
# * Like in cricket, each match has two innings:
#     -   1st inning:
#         *   $N$ Question from the Q-agent (Team-A) and their corresponding $N$ answers from the A-agent (Team-B).
#         *   Q-agent score (Team-A): Say, $40$
#         *   A-agent score (Team-B): $60$
#
#     -   2nd inning:
#         *   $N$ Question from the Q-agent (Team-B) and their respective $N$ responses from the A-agent (Team-A).
#         *   Q-agent score (Team-B): Say, $70$
#         *   A-agent score (Team-A): $30$
#     -   Final Score:
#         *   Team-A score $=$ 1st inning Q-agent score $+$ 2nd inning A-agent score $= 40 + 30 = 70$
#         *   Team-B score $=$ 1st inning A-agent score $+$ 2nd inning Q-agent score $= 60 + 70 = 130$
#     -   Winner: **Team-B** with a score of $130$.
#
# For more info on how scoring is done, refer to the [scoring criteria section](#scoring-criteria).

# %% [markdown]
# ## Guidelines
# <!-- 📋  -->
#
# ### Format
# We will only consider responses from the Q-agent and the A-agent which follow the below format.
#
# *Note*: While having an explanation/reasoning is a plus, not having them doesn't disqualify the question or answer being correct.
#
# #### Q-Agent
# Given a topic, the Q-agent should generate questions in the specified JSON format:
#
# ```json
# {
#     "topic": "<Topic of the Question>",
#     "question": "<full question text>",
#     "choices": [
#         "A) <choice A text>",
#         "B) <choice B text>",
#         "C) <choice C text>",
#         "D) <choice D text>"
#     ],
#     "answer": "<correct choice letter only>",
#     "explanation": "brief explanation within 100 words for why the answer is correct"
# }
# ```
#
# The **"Topic"**, **"Question"**, **"Choices"**, and **"Answer"** will be verified for correctness.
#
# #### A-Agent
# Given a Question and Choices, A-agent should produce answer in the format of:
#
# ```json
# {
#     "answer": "<correct choice letter only>",
#     "reasoning": "brief reasoning within 100 words for why the answer is correct"
# }
# ```
#
# The **"Answer"** key will be compared with **"Answer"** from the opponent's Q-agent.
#
# **<u>Note</u>**: *Once again, we will **only** consider those responses from the Q-agent and the A-agent which follow the above format.*

# %% [markdown]
# ## Submission
# <!-- 🛠️  -->
# You need to submit your code which should contain these main files:
# 1. All work must be within the `AAIPL` folder. Do NOT change the folder name.
# 1. No need to upload anything anywhere, we'll collect your agent code from your Jupyter Server at the end of the challenge.
#    1. The agents will be called by `python -m agents.question_agent` and `python -m agents.answer_agent`, respectively.
# 1. ENSURE model checkpoint(s) (e.g., `model.safetensors` or `.pt` or `.pth`) is (are) loading and expected files are getting generated from Q-agent and A-agent, when inference is done.
#    1. Outputs must be saved to `outputs/questions.json` and `outputs/answers.json`, respectively.
# 1. **<u>Note</u>: You are not required to generate any `.json` for us, we'll do that for you during evaluation setting a specific value to $N$.**
#
# You can test your submission by running the commands in the [Getting Started](#getting-started) section.
#
# <u><span style="color: blue">Note</span></u>: These files will be checked for any hardcoding, RAG, or other unfair practices.<br>
# <u><span style="color: red">Remarks / Caution</span></u>: A-agent is equally important as Q-agent. So, please do focus on both.

# %% [markdown]
# ## Restrictions
# <!-- ⚠️ -->
#
# 1.  **<span style="color: red">NO</span> LAST Minute Submission**: The submission deadline is strict. Any changes to your code after the deadline may disqualify your submission.
# 1.  RAG (Retrieval Augmented Generation) techniques are not allowed.
# 1.  Adversarial approaches will lead to disqualification, e.g. making A-agents hallucinate.
# 1.  Usage of models other than what was provided will lead to disqualification.
# 1.  Only English language is allowed for both Q-agent and A-agent.
# 1.  Strictly stay within the `max_tokens` limits specified in `agen.yaml` & `qgen.yaml`. Other parameters can be changed.
# 1.  Questions must pertain to the topics listed in `topics.json`.
# 1.  Each question should be generated under `13 secs`. Questions exceeding this limit will not be considered.
# 1.  Each answer should be generated under `9 secs`. Answers exceeding this limit will not be considered.
#
# Feel free to reach out in the Discord channel for any clarifications or questions!

# %% [markdown]
# ## Directory & Files overview
# <!-- 📂  -->
#
# ```plaintext
# .
# ├── agents
# │   ├── question_model.py
# │   ├── question_model_llama.py (example code using Unsloth Llama)
# │   ├── question_agent.py
# │   ├── answer_model.py
# │   ├── answer_model_llama.py (example code using Unsloth Llama)
# │   └── answer_agent.py
# ├── assets
# │   ├── topics_example.json # example questions w.r.t each topic
# │   ├── topics.json # Topics on which we require to generate questions
# │   ├── sample_question.json # File specifying expected format of questions generated
# │   └── sample_answer.json # Expected format of answers generated
# ├── utils
# │   └── build_prompt.py # prompt-tuning scripts
# ├── README.ipynb
# ├── tutorial.ipynb # Synthetic Data Generation and Unsloth Tutorial
# ├── tutorial_config.yaml # Config file for tutorial
# ├── qgen.yaml # Generation specific parameters for Q-agent
# └── agen.yaml # Generation specific parameters for A-agent
# ```

# %% [markdown]
# ## Getting started
# <!-- 🎮  -->
# Let's get started with running the Q-agent and A-agent framework.
#
# ### Environment Setup
# <!-- 🚀 -->

# %%
# Import basic packages
import json
from typing import Dict, Any, List

# %% [markdown]
# ### Q-Agent
# <!-- 🤔 -->
# You will update the model in `question_model.py`, which will be invoked by `question_agent.py`. In the provided skeleton, we have used the base Qwen3-4B model for Q-Agent but you should experiment with other models and techniques. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.
#
# Generated questions must pertain to the topics mentioned in `topics.json` file. Additional topics will be added for the tournament finals.
#
# __Topics:__
# 1.  `Logical Reasoning`: Syllogisms
# 2.  `Puzzles`: Seating Arrangements (Linear, Circular)
# 3.  `Blood Relations and Family Tree`: Puzzles involving generations and family tree logic
# 4.  `Alphanumeric Series`: Mixed series questions
#
# Sample questions and answers are available in the [assets folder](./assets).

# %%
# Run the following code to generate questions.
# For demo purpose, we have used the base Qwen3-4B model for Q-Agent. Participants are expected to improve upon this
# !python -m agents.question_agent \
    --output_file "outputs/questions.json" \
    --num_questions 50 \
    --verbose
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# #### Unsloth: `hf_xet==1.1.10` and `ipykernel>6.30.1` breaks progress bars. Disabling for now in XET.
# #### Unsloth: To re-enable progress bars, please downgrade to `ipykernel==6.30.1` or wait for a fix to
# https://github.com/huggingface/xet-core/issues/526
# INFO 02-15 09:18:54 [__init__.py:225] Automatically detected platform rocm.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: AMD currently is not stable with 4bit bitsandbytes. Disabling for now.
# ==((====))==  Unsloth 2025.10.9: Fast Qwen2 patching. Transformers: 4.56.2. vLLM: 0.11.1rc3.dev39+gf417746ad.rocm700.
#    \\   /|    . Num GPUs = 1. Max memory: 255.688 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0a0+git1c57644. ROCm Toolkit: 7.0.51831-a3e329ad8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards: 100%|██████████████████| 8/8 [00:19<00:00,  2.45s/it]
# Unsloth 2025.10.9 patched 48 layers with 48 QKV layers, 48 O layers and 48 MLP layers.
# Loaded successfully ✅
# STEPS: 100%|████████████████████████████████████| 10/10 [01:11<00:00,  7.12s/it]
# Generated 50 questions!
# {"topic":"Seating Arrangements (Linear, Circular)","question":"There are five men named A, B, C, D, and E facing south and five ladies named M, N, O, P, and Q facing north in a line parallel to the first line. Q is situated across from B and to the left of D. C and N are positioned on opposite sides of the diagonal. E is directly facing O, who is to the right of M. P, on the left of Q, is on the opposite side of D. M is positioned at one end of the line. If O and P, A and E, and B and Q exchange positions, who will be the second person to the right of the person opposite to the second person to the right of P?","choices":["A) D","B) A","C) E","D) O"],"answer":"A","explanation":"After swaps: Men: C-A-D-Q-E; Ladies: M-P-O-B-N. P's second right is B. B's opposite is Q. Q's second right is D."}
# {"topic":"Syllogisms","question":"Statement I: Some cats are dogs. Statement II: All dogs are birds. Statement III: Some birds are fish. Conclusions I: Some fish are dogs. Conclusion II: Some birds are cats.","choices":["A) A) If only conclusion II follows","B) B) If only conclusion I follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"A","explanation":"Some cats are dogs does not imply any direct relationship between cats and birds. All dogs being birds means some birds can be cats but no fish-dog connection is established."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, E sit in a row facing north. A sits next to B but not next to E. C sits next to both D and E. Who sits second to the right of the person sitting opposite B if they stand up and rearrange themselves in a circular fashion maintaining their relative positions?","choices":["A) A) A","B) B) C","C) C) D","D) D) E"],"answer":"D","explanation":"In the row, CDEBA maintains adjacency rules. In circle, same order applies. Opposite B is D. Second to D's right is E."}
# {"topic":"Syllogisms","question":"Statement I: Some cats are dogs.Statement II: All dogs are animals.Statement III: Some animals are birds.Conclusions I: Some birds are dogs.Conclusion II: Some animals are cats.","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"No direct link shows birds are dogs. Animals include cats, so II follows."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a linear seating arrangement, five friends A, B, C, D, E sit facing north. Across from them, five friends F, G, H, I, J sit facing south. A faces G, B is to the immediate left of A, C faces H, D is immediately to the left of C. If B and H swap places, who will be to the immediate right of the person now facing the one originally facing D?","choices":["A) A) F","B) B) G","C) C) I","D) D) J"],"answer":"D","explanation":"Initially, A faces G, B (left of A) faces F, C faces H, D (left of C) faces I, E faces J. After swap, B faces F and H faces G. D still faces I but now I is to the immediate right of J."}
# {"topic":"Family tree logic","question":"Rajiv states, \"He is the brother of my mother's only daughter.\" How is Rajiv related to the man mentioned?","choices":["A) A) Nephew","B) B) Brother","C) C) Son","D) D) Cousin"],"answer":"B","explanation":"Rajiv's mother's only daughter is Rajiv himself. Hence, the man referred to is Rajiv's brother."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, and E are sitting in a row facing north. C is between A and D, and B is to the immediate right of D. If E is not next to B, who is sitting second to the left of C?","choices":["A) A) A","B) B) B","C) C) D","D) D) E"],"answer":"D","explanation":"C is between A and D, thus order around C is A-C-D. Since B is immediately right of D, it's A-C-D-B. E cannot be next to B, leaving E as the only option for the second position left of C."}
# {"topic":"Mixed Series (Alphanumeric)","question":"PQR2, STU3, VWX4, YZA5, _____","choices":["A) A) ABC6","B) B) BCD6","C) C) CDE6","D) D) DEF6"],"answer":"A","explanation":"The first three letters move forward by 3 positions each time while the number increases by 1 each step. Hence, the sequence continues with ABC6."}
# {"topic":"Family tree logic","question":"Rajesh says, \"He is the son of my father’s only sibling.\" How is Rajesh related to the person he is describing?","choices":["A) A) Nephew","B) B) Brother","C) C) Cousin","D) D) Uncle"],"answer":"C","explanation":"Rajesh's father's only sibling is his uncle or aunt. The son of this sibling is Rajesh's cousin."}
# {"topic":"Family tree logic","question":"Rajesh says, \u0022He is the brother of my father\u0027s only daughter.\u0022 How is Rajesh related to him?","choices":["A) A) Brother","B) B) Uncle","C) C) Nephew","D) D) Cousin"],"answer":"C","explanation":"Rajesh\u0027s father\u0027s only daughter is Rajesh\u0027s sister. So, the brother of Rajesh\u0027s sister is Rajesh himself, making Rajesh the nephew of the man he describes."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a linear arrangement, six friends A, B, C, D, E, F sit in a row facing North. A sits second from the left. B sits third to the right of A. C sits second to the left of B. D sits at one of the ends. E is not an immediate neighbor of D. F is not next to A or C. Who sits third from the right?","choices":["A) A) A","B) B) C","C) C) F","D) D) E"],"answer":"C","explanation":"Arrangement from left to right: D, A, C, B, F, E. F is third from the right."}
# {"topic":"Syllogisms","question":"Statement I: All cats are dogs. Statement II: No dog is a bird. Statement III: Some birds are fish. Conclusions I: No cat is a bird. Conclusion II: Some fish being cats is a possibility.","choices":["A) A) If only conclusion I follow","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"C","explanation":"From Statement I and II, no cat can be a bird; thus, Conclusion I is true. However, there's no direct link proving fish are cats, making Conclusion II a mere possibility."}
# {"topic":"Mixed Series (Alphanumeric)","question":"XYZ_9, WVU_7, TST_5, RQP_3, PON_1, ___","choices":["A) A) MLK_0","B) B) NOP_0","C) C) LMN_0","D) D) NML_0"],"answer":"C","explanation":"The first part of the sequence decreases by skipping one letter each time. The numerical sequence decreases by 2 each step. Thus, after PON_1 comes LMN_0."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, and E are sitting in a row facing north. B is to the immediate left of C, who is not at either end. D is to the immediate right of E. A is not next to B. If they all shift one place to the right, who will be in the middle?","choices":["A) A) A","B) B) B","C) C) C","D) D) D"],"answer":"C","explanation":"Initially, the order is E-D-B-C-A. Shifting one place to the right results in A-E-D-B-C. Therefore, C is in the middle."}
# {"topic":"Syllogisms","question":"Statement I: All birds are animals
# Statement II: Some animals are mammals
# Statement III: All mammals are vertebrates
# Conclusions I: Some vertebrates are animals
# Conclusion II: All birds are vertebrates","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"Some vertebrates being animals is implied by all mammals being vertebrates and some animals being mammals. Not all birds are vertebrates directly from given statements."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB_1, CD_2, EF_3, GH_4, ___","choices":["A) A) IJ_5","B) B) HI_5","C) C) JK_5","D) D) IJ_4"],"answer":"A","explanation":"The pattern involves alternating alphabetical sequences with ascending numbers: A-B, C-D, E-F, G-H followed by I-J with number incrementing by 1 from previous term's number."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB_1, CD_2, EF_3, GH_4, ___","choices":["A) A) IJ_5","B) B) HI_5","C) C) JK_5","D) D) KL_5"],"answer":"A","explanation":"The first two letters form consecutive pairs in the alphabet while maintaining their positions (first letter odd, second letter even). The number sequence increments by 1. Hence IJ_5."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, E are sitting in a row facing North. B sits third from the left. C is immediately to the right of A. D is between B and E. Who is second from the left?","choices":["A) A) A","B) B) B","C) C) C","D) D) D"],"answer":"A","explanation":"Given B is third from the left, and D is between B and E, A must be second from the left since C is immediately to the right of A."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB2, CD4, EF6, GH8, ______","choices":["A) A) IJ10","B) B) HI10","C) C) JK9","D) D) IJ8"],"answer":"A","explanation":"The series alternates between increasing letters and numbers. Letters advance by two alphabets each time, while the numbers double from the previous increment."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a row facing north, five friends A, B, C, D, and E sit such that A is between B and C, and D is to the immediate right of E. If they all turn around to face south and then C and E swap places, who is now to the immediate left of B?","choices":"A) A) C;B) B) E;C) C) A;D) D) D","answer":"D","explanation":"Initially, the order is BACDE. After turning around and swapping C and E, the order becomes BECAD. Thus, D is immediately left of B."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a linear arrangement facing each other, five men A, B, C, D, E face five women F, G, H, I, J. A faces G, who is to the immediate left of H. C is immediately to the right of A. B is to the immediate left of D, who faces I. J is at one end. If G and H swap places, who is directly opposite the second person to the right of G?","choices":["A) A) F","B) B) H","C) C) J","D) D) I"],"answer":"D","explanation":"G initially faces A, H faces C. After swap, G now faces C, H faces A. Second to G's right is H. Directly opposite H is I."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"In a circular arrangement, six friends A, B, C, D, E, and F sit around a table. A sits opposite B, C is between D and E, and F is to the immediate right of A. Who is sitting to the immediate left of D?","choices":["A) A) E","B) B) C","C) C) F","D) D) B"],"answer":"A","explanation":"Since C is between D and E and A is opposite B with F to the immediate right of A, placing all correctly shows E immediately to the left of D."}
# {"topic":"Family tree logic","question":"Rajesh says, \u0022He is the son of my mother\u0027s only daughter.\u0022 How is Rajesh related to the boy?","choices":["A) A) Uncle","B) B) Father","C) C) Brother","D) D) Cousin"],"answer":"B","explanation":"Since Rajesh's mother has only one daughter who is Rajesh himself, the boy mentioned is Rajesh's own child making Rajesh the boy's Father."}
# {"topic":"Family tree logic","question":"Rajesh says, \u0022He is the son of my father\u0027s only sibling.\u0022 How is Rajesh related to the person he is referring to?","choices":["A) A) Nephew","B) B) Brother","C) C) Cousin","D) D) Son"],"answer":"C","explanation":"Rajesh\u0027s father\u0027s only sibling is his uncle or aunt. The son of an uncle or aunt is Rajesh\u0027s cousin."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB2, CD4, EF6, GH8, ______","choices":["A) A) IJ10","B) B) IK10","C) C) IJ9","D) D) IK9"],"answer":"A","explanation":"The pattern involves alternating between increasing alphabetical letters and even numbers. First letters increase by one alphabet each step, second letters follow similarly, and the numbers increment by 2 each time."}
# {"topic":"Syllogisms","question":"Statement I: All books are pens; Statement II: No pen is a pencil; Statement III: Some pencils are erasers; Conclusions I: No book is a pencil; Conclusion II: Some erasers are not books","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"From Statements I and II, no book is a pencil, confirming Conclusion I. However, since pencils can be erasers but books cannot be pencils, it's impossible for any book to be an eraser, making Conclusion II logically true."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB_1, CD_2, EF_3, GH_4, _____","choices":["A) A) IK_5","B) B) IJ_5","C) C) HI_5","D) D) JK_5"],"answer":"B","explanation":"The pattern alternates between increasing the first two letters alphabetically and maintaining their order while incrementing the numerical value by 1. Thus, the next term should start with IJ and have the number 5."}
# {"topic":"Family tree logic","question":"Rajesh introduces a man as his maternal uncle's son. How is the man related to Rajesh?","choices":["A) A) Cousin","B) B) Brother","C) C) Uncle","D) D) Nephew"],"answer":"C","explanation":"Rajesh's maternal uncle's son would be Rajesh's mother's brother's son which makes him Rajesh's Uncle."}
# {"topic":"Syllogisms","question":"Statement I: Some cats are dogs. Statement II: All dogs are mammals. Statement III: Some mammals are birds. Conclusions I: Some mammals are cats. Conclusion II: Some birds are dogs.","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"C","explanation":"Some cats being dogs and all dogs being mammals implies some mammals are cats. There's no direct link between birds and dogs."}
# {"topic":"Syllogisms","question":"Statement I: All cats are mammals. Statement II: Some mammals are dogs. Statement III: No dog is a cat. Conclusions I: Some dogs are mammals. Conclusion II: No mammal is a cat.","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"C","explanation":"All cats are mammals does not imply no mammal is a cat; however, some mammals being dogs is true."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB_2, CD_4, EF_6, GH_8, ______","choices":["A) A) IJ_10","B) B) HI_9","C) C) IJ_10","D) D) JK_12"],"answer":"C","explanation":"The pattern involves increasing letters in pairs AB, CD, EF, GH followed by even numbers incrementing by 2: 2, 4, 6, 8. Thus, the next pair is IJ with the number 10."}
# {"topic":"Syllogisms","question":"Statement I: Some dogs are cats
# Statement II: All cats are birds
# Statement III: Some birds are fish
# Conclusions I: Some fish are cats
# Conclusion II: Some birds are dogs","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"D","explanation":"There's no direct link proving fish are cats or birds are dogs."}
# {"topic":"Syllogisms","question":"Statement I: All dogs are mammals. Statement II: Some mammals are pets. Conclusion I: Some pets are dogs. Conclusion II: Some dogs are pets.","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"While all dogs are mammals, the second statement does not ensure that any dogs are among the pets. Thus, only conclusion II follows as it's a restatement with no additional certainty."}
# {"topic":"Family tree logic","question":"Rahul says, “He is the son of my mother’s only sibling.” How is the boy related to Rahul?","choices":["A) A) Cousin","B) B) Brother","C) C) Nephew","D) D) Uncle"],"answer":"A","explanation":"My mother's only sibling is Rahul's aunt or uncle. The son of Rahul's aunt or uncle makes him Rahul's cousin."}
# {"topic":"Family tree logic","question":"Rajesh introduces his friend by saying, \u0022This is my uncle\u0027s son\u0027s daughter.\u0022 How is Rajesh related to the girl?","choices":["A) A) Cousin","B) B) Niece","C) C) Sister","D) D) Daughter"],"answer":"D","explanation":"Rajesh\u0027s uncle\u0027s son would be Rajesh\u0027s cousin. The daughter of Rajesh\u0027s cousin makes Rajesh the father of the girl; thus, she is his Daughter."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB2, CD4, EF6, GH8, ____","choices":["A) A) IJ10","B) B) HI10","C) C) IJ9","D) D) HI9"],"answer":"A","explanation":"Each pair of letters progresses alphabetically by two, while the numbers increase by 2 each time. Thus, after GH8 comes IJ10."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB2, CD4, EF6, GH8, ______","choices":["A) A) IK10","B) B) IJ10","C) C) HI9","D) D) JK12"],"answer":"B","explanation":"The pattern involves increasing letters by two positions in the alphabet and doubling the numbers sequentially from 2 to 4 to 6 to 8 to 10."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB2, CD4, EF6, GH8, _____","choices":["A) A) IJ10","B) B) JK9","C) C) KL8","D) D) LM7"],"answer":"A","explanation":"Each pair of letters progresses alphabetically by two, while the numbers increase sequentially by 2. Thus, the next term should be IJ10."}
# {"topic":"Family tree logic","question":"Rahul says, \u0022He is the brother of my father\u0027s only daughter.\u0022 How is the man related to Rahul?","choices":["A) A) Uncle","B) B) Brother","C) C) Cousin","D) D) Nephew"],"answer":"B","explanation":"Rahul\u0027s father\u0027s only daughter is Rahul\u0027s sister. The brother of Rahul\u0027s sister is Rahul\u0027s brother."}
# {"topic":"Syllogisms","question":"Statement I: All cats are mammals
# Statement II: Some mammals are dogs
# Statement III: No dog is a cat
# Conclusions I: Some mammals are not cats
# Conclusion II: All cats are dogs","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"A","explanation":"Since all cats are mammals but no dog is a cat, some mammals can indeed not be cats. Conclusion II contradicts Statement III."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB2, CD4, EF6, GH8, ______","choices":["A) A) IJ9","B) B) IJ10","C) C) IK9","D) D) IK10"],"answer":"B","explanation":"The pattern involves increasing alphabetical letters and even numbers by 2. Hence, IJ10 follows."}
# {"topic":"Family tree logic","question":"Raj points to a man and says, \u0022He is the brother of my father\u0027s only daughter.\u0022 How is the man related to Raj?","choices":["A) A) Uncle","B) B) Brother","C) C) Cousin","D) D) Son"],"answer":"A","explanation":"Raj\u0027s father\u0027s only daughter is Raj\u0027s sister. The brother of Raj\u0027s sister is Raj\u0027s uncle."}
# {"topic":"Mixed Series (Alphanumeric)","question":"AB2, CD4, EF6, GH8, _____","choices":["A) A) IJ10","B) B) IK9","C) C) IJ8","D) D) IL10"],"answer":"A","explanation":"Each term consists of two consecutive letters followed by an even number that increases by 2 each time. Hence IJ10."}
# {"topic":"Family tree logic","question":"Rajesh introduces his friend saying, “This is the son of my father’s only sibling.” How is Rajesh’s friend related to Rajesh?","choices":["A) A) Brother","B) B) Nephew","C) C) Cousin","D) D) Son"],"answer":"C","explanation":"Rajesh's father's only sibling is his uncle or aunt. The son of this uncle/aunt is Rajesh's cousin."}
# {"topic":"Syllogisms","question":"Statement I: All dogs are animals. Statement II: Some animals are cats. Statement III: No cat is a bird. Conclusions I: Some birds are animals. Conclusion II: Some animals are dogs.","choices":["A) A) If only conclusion II follows","B) B) If only conclusion I follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"A","explanation":"All dogs are animals supports conclusion II. No support for birds being animals directly."}
# {"topic":"Syllogisms","question":"Statement I: All dogs are mammals. Statement II: Some mammals are cats. Conclusion I: Some cats are dogs. Conclusion II: Some mammals are dogs.","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"B","explanation":"While all dogs are mammals, there's no information linking cats directly to dogs. However, since all dogs are mammals, it confirms some mammals are dogs."}
# {"topic":"Family tree logic","question":"Rahul says, \"He is the son of my mother's only sibling.\" How is the boy related to Rahul?","choices":["A) A) Nephew","B) B) Cousin","C) C) Brother","D) D) Son"],"answer":"B","explanation":"Rahul's mother's only sibling is his aunt. The son of his aunt is his cousin."}
# {"topic":"Seating Arrangements (Linear, Circular)","question":"Five friends A, B, C, D, and E are seated around a circular table facing outward. A is between B and C. D is to the immediate right of C. If E is not next to A, who is sitting to the immediate left of B?","choices":["A) A) C","B) B) D","C) C) A","D) D) E"],"answer":"C","explanation":"Given A is between B and C, and D is immediately right of C, we place them as BACD. Since E is not next to A, E must be to the immediate left of B making the order EBCAD. Thus, A is to the immediate left of B."}
# {"topic":"Family tree logic","question":"Rajesh says, \u0022He is the brother of my father\u0027s only son.\u0022 How is Rajesh related to him?","choices":["A) A) Brother","B) B) Cousin","C) C) Uncle","D) D) Nephew"],"answer":"A","explanation":"Rajesh's father's only son is Rajesh himself. So, the brother of Rajesh is directly his sibling, making him Rajesh's Brother."}
# {"topic":"Syllogisms","question":"Statement I: All dogs are animals
# Statement II: Some animals are birds
# Statement III: No bird is a fish
# Conclusions I: Some animals are not fish
# Conclusion II: Some dogs are birds","choices":["A) A) If only conclusion I follows","B) B) If only conclusion II follows","C) C) If conclusion I and II both follow","D) D) If neither conclusion I nor conclusion II follows"],"answer":"A","explanation":"Since no bird is a fish, some animals can be non-fish. Dogs cannot be birds based on given statements."}
#
# ==================================================
#
#
# Time taken per batch generation: [21.912579774856567, 5.367582559585571, 5.590141773223877, 5.311105489730835, 6.359622478485107, 5.595580101013184, 5.348618268966675, 4.885593414306641, 4.916321039199829, 5.8531174659729]
# Tokens generated per batch: [1140, 790, 800, 740, 900, 800, 760, 685, 690, 825]
# Total Time Taken: 71.140 seconds; Total Tokens: 8130; TGPS: 114.281 seconds
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Saved to outputs/questions.json!

# %% [markdown]
# #### Basic format-checks for questions from Q-agent
#
# Generated questions must follow the [format instructions](#format-overview). All questions generated from the Q-agent will be filtered and validated before being sent to the opponent's A-agent. We generate two version of questions, one is the raw, unfiltered one `questions.json` and the other is `filtered_questions.json` after passing through the below example filter. The full filtering and validation process is part of the judging system and is not demonstrated here.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-4B", padding_side='left')

def count_tokens_q(text: str) -> int:
    """Count the number of tokens using Qwen3-4B tokenizer"""
    return len(tokenizer.encode(text, add_special_tokens=False))

def filter_questions(questions: List[str|Dict[str, str|Any]]) -> List[Dict[str, str|Any]]:
    def basic_checks(q2: Dict[str, str])->bool:
        # check required keys
        required_keys = ['topic', 'question', 'choices', 'answer']
        if all((key in q2) for key in required_keys):
            # check choices format
            checks = all(isinstance(choice, str) and len(choice) > 2 and choice[0].upper() in 'ABCD' for choice in q2['choices'])
            if isinstance(q2['choices'], list) and len(q2['choices']) == 4 and checks:
                # check answer format
                # Check token length
                check_len = sum(count_tokens_q(q2[k]) for k in ['question', 'answer'])
                check_len += sum(count_tokens_q(choice) for choice in q2['choices']) - 15
                if check_len < 130:
                    if check_len + count_tokens_q(q2.get('explanation', 'None')) <= 1024:
                        # Extra Checks: (PLUS checks) len(q2['answer']) == 1 and q2['answer'].upper() in 'ABCD':
                        if isinstance(q2['answer'], str):
                            return True
        return False
    correct_format_question = []
    for i, q in enumerate(questions):
        if isinstance(q, dict):
            if basic_checks(q):
                correct_format_question.append(q)
        elif isinstance(q, str):
            try:
                q1 = json.loads(q)
                if basic_checks(q1):
                    correct_format_question.append(q1)
            except json.JSONDecodeError:
                # If JSON decoding fails, skip this answer
                print(f"Skipping invalid JSON at index {i}: {q}")
                continue
        else:
            continue
    if len(correct_format_question) >= 0.5 * len(questions):
        return correct_format_question
    return list()

# %%
with open("outputs/questions.json", "r") as f:
    questions = json.load(f)

filtered_questions = filter_questions(questions)

with open("outputs/filtered_questions.json", "w") as f:
    json.dump(filtered_questions, f, indent=4)

print(f"Number of questions: {len(questions)}")
print(f"Number of filtered questions: {len(filtered_questions)}")

# %% [markdown]
# ### A-agent
# <!-- 🤖  -->
# You will update the model in `answer_model.py`, which will be invoked by `answer_agent.py`. In the provided skeleton, we have again used the base Qwen3-4B model for A-Agent but you should experiment with other models and techniques. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.

# %%
# Same instructions apply for the answer agent.
# For demo purpose, we have used the base Qwen3-4B model for A-agent. Participants are expected to improve upon this.
# !python -m agents.answer_agent \
    --input_file "outputs/filtered_questions.json" \
    --output_file "outputs/answers.json" \
    --verbose
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# #### Unsloth: `hf_xet==1.1.10` and `ipykernel>6.30.1` breaks progress bars. Disabling for now in XET.
# #### Unsloth: To re-enable progress bars, please downgrade to `ipykernel==6.30.1` or wait for a fix to
# https://github.com/huggingface/xet-core/issues/526
# INFO 02-15 09:21:08 [__init__.py:225] Automatically detected platform rocm.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: AMD currently is not stable with 4bit bitsandbytes. Disabling for now.
# ==((====))==  Unsloth 2025.10.9: Fast Qwen2 patching. Transformers: 4.56.2. vLLM: 0.11.1rc3.dev39+gf417746ad.rocm700.
#    \\   /|    . Num GPUs = 1. Max memory: 255.688 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0a0+git1c57644. ROCm Toolkit: 7.0.51831-a3e329ad8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards: 100%|██████████████████| 8/8 [00:20<00:00,  2.53s/it]
# Unsloth 2025.10.9 patched 48 layers with 48 QKV layers, 48 O layers and 48 MLP layers.
# STEPS: : 11batch [00:50,  4.60s/batch]
#
# === Question 1 ===
# Question: Statement I: Some cats are dogs. Statement II: All dogs are birds. Statement III: Some birds are fish. Conclusions I: Some fish are dogs. Conclusion II: Some birds are cats.
# Expected: A
# Model Answer:
# {
#     "answer": "D",
#     "reasoning": "Statement I says some cats are dogs, but this does not imply any direct relationship between cats and birds or fish. Statement II says all dogs are birds, which means some birds can be dogs, but it doesn't establish a connection where some fish are dogs. Statement III says some birds are fish, but there's no link provided to conclude either statement directly. Hence, neither conclusion follows."
# }
#
# === Question 2 ===
# Question: Five friends A, B, C, D, E sit in a row facing north. A sits next to B but not next to E. C sits next to both D and E. Who sits second to the right of the person sitting opposite B if they stand up and rearrange themselves in a circular fashion maintaining their relative positions?
# Expected: D
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "In the row, A is next to B but not E, implying A is between B and C/D. Since C is next to both D and E, C must be at one end with D and E next to it. Thus, the arrangement could be D-C-A-B-E or E-C-A-B-D. In a circle, B's opposite is E or D. Second to the right of E/D is C."
# }
#
# === Question 3 ===
# Question: Statement I: Some cats are dogs.Statement II: All dogs are animals.Statement III: Some animals are birds.Conclusions I: Some birds are dogs.Conclusion II: Some animals are cats.
# Expected: B
# Model Answer:
# {
#     "answer": "D",
#     "reasoning": "Statement I suggests some overlap between cats and dogs but does not imply any direct relationship with birds. Statement II states all dogs are animals, which supports that some animals are cats from Statement I. However, there's no logical connection implying some birds are dogs (Conclusion I). Therefore, only Conclusion II logically follows."
# }
#
# === Question 4 ===
# Question: In a linear seating arrangement, five friends A, B, C, D, E sit facing north. Across from them, five friends F, G, H, I, J sit facing south. A faces G, B is to the immediate left of A, C faces H, D is immediately to the left of C. If B and H swap places, who will be to the immediate right of the person now facing the one originally facing D?
# Expected: D
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "Initially, A faces G, B is to the left of A, C faces H, and D is to the left of C. This means the order is B-A-D-C-E facing north, and G-F-H-I-J facing south. After B and H swap, B is now facing south and H is facing north. The person originally facing D is H, so we need the person to the right of H, which is I."
# }
#
# === Question 5 ===
# Question: Rajiv states, "He is the brother of my mother's only daughter." How is Rajiv related to the man mentioned?
# Expected: B
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "Rajiv states he is the brother of the man's mother's only daughter, which means he is the brother of the man himself. Therefore, Rajiv is the man's son."
# }
#
# === Question 6 ===
# Question: Five friends A, B, C, D, and E are sitting in a row facing north. C is between A and D, and B is to the immediate right of D. If E is not next to B, who is sitting second to the left of C?
# Expected: D
# Model Answer:
# {
#     "answer": "D",
#     "reasoning": "C is between A and D, so the arrangement includes A-C-D or D-C-A. Since B is immediately to the right of D, it must be D-C-B. Given E is not next to B, E can only sit at the far left position, making the sequence E-A-C-D-B. Thus, the person second to the left of C is E."
# }
#
# === Question 7 ===
# Question: PQR2, STU3, VWX4, YZA5, _____
# Expected: A
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "The pattern involves shifting to the next set of three consecutive letters followed by an incrementing number. Starting from PQR2, moving to STU3, VWX4, and YZA5, the next sequence should follow the same rule, leading to DEF6."
# }
#
# === Question 8 ===
# Question: Rajesh says, "He is the son of my father’s only sibling." How is Rajesh related to the person he is describing?
# Expected: C
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "Rajesh's father has only one sibling, meaning they are siblings. The person described is the child of this sibling. Therefore, Rajesh is the cousin of the person described."
# }
#
# === Question 9 ===
# Question: Rajesh says, "He is the brother of my father's only daughter." How is Rajesh related to him?
# Expected: C
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "Rajesh states he is the brother of Rajesh's father's only daughter. This means Rajesh's father has one daughter, who is Rajesh’s sister. Therefore, Rajesh is the nephew of the person being addressed."
# }
#
# === Question 10 ===
# Question: In a linear arrangement, six friends A, B, C, D, E, F sit in a row facing North. A sits second from the left. B sits third to the right of A. C sits second to the left of B. D sits at one of the ends. E is not an immediate neighbor of D. F is not next to A or C. Who sits third from the right?
# Expected: C
# Model Answer:
# {
#     "answer": "D",
#     "reasoning": "A sits second from the left, so the arrangement starts with _A_. B sits third to the right of A, placing B fourth. C sits second to the left of B, placing C second. D sits at one end, but since E is not an immediate neighbor of D and F is not next to A or C, D must be on the far right. Thus, the sequence is D_F_C_A_B_E, making E the third from the right."
# }
#
# === Question 11 ===
# Question: Statement I: All cats are dogs. Statement II: No dog is a bird. Statement III: Some birds are fish. Conclusions I: No cat is a bird. Conclusion II: Some fish being cats is a possibility.
# Expected: C
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "Statement I implies all cats are dogs, so no cat can be a bird based on Statement II (no dog is a bird). Thus, Conclusion I logically follows. However, Conclusion II cannot be derived because there's no direct link between fish and cats. Therefore, only Conclusion I follows."
# }
#
# === Question 12 ===
# Question: XYZ_9, WVU_7, TST_5, RQP_3, PON_1, ___
# Expected: C
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "The pattern decreases alphabetically and numerically by 2 for each term. Starting from XYZ_9, each subsequent term shifts the letters two places backward and reduces the number by 2. Following this, after PON_1, the next sequence should be LMN_0."
# }
#
# === Question 13 ===
# Question: Five friends A, B, C, D, and E are sitting in a row facing north. B is to the immediate left of C, who is not at either end. D is to the immediate right of E. A is not next to B. If they all shift one place to the right, who will be in the middle?
# Expected: C
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "B is immediately left of C, so BC are together. C is not at either end, thus BC can be in positions 2-3 or 3-4. D is immediately right of E, so ED can be in positions 2-3 or 3-4. Since A is not next to B, BC must be in 3-4 and ED in 2-3. Thus, initial order is EDBCA. Shifting one place right gives DBCEA, making C the middle person."
# }
#
# === Question 14 ===
# Question: Statement I: All birds are animals Statement II: Some animals are mammals Statement III: All mammals are vertebrates Conclusions I: Some vertebrates are animals Conclusion II: All birds are vertebrates
# Expected: B
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "From Statement I, all birds are animals. From Statement II and III, some animals are mammals and all mammals are vertebrates. Hence, some vertebrates are indeed animals, supporting Conclusion I. Since all birds are animals and some animals are mammals, and all mammals are vertebrates, it implies all birds are vertebrates, supporting Conclusion II. Thus, both conclusions logically follow."
# }
#
# === Question 15 ===
# Question: AB_1, CD_2, EF_3, GH_4, ___
# Expected: A
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "The pattern involves consecutive pairs of letters followed by increasing numbers. The sequence starts with AB_1, CD_2, EF_3, GH_4, so the next pair should follow this pattern. The next pair after GH would be IJ, and the number increments to 5. Thus, the correct option is IJ_5."
# }
#
# === Question 16 ===
# Question: AB_1, CD_2, EF_3, GH_4, ___
# Expected: A
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "The pattern follows alphabetical order with consecutive letters followed by a number incrementing by one. Each pair of letters moves two steps forward in the alphabet from the previous pair. Thus, after GH, the next pair should be IJ, and the number should be 5."
# }
#
# === Question 17 ===
# Question: Five friends A, B, C, D, E are sitting in a row facing North. B sits third from the left. C is immediately to the right of A. D is between B and E. Who is second from the left?
# Expected: A
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "B is third from the left, so the positions could be _ _ B _ _. C is immediately to the right of A, meaning A and C must be together. Since D is between B and E, the arrangement becomes A C B D E, making C the second from the left."
# }
#
# === Question 18 ===
# Question: AB2, CD4, EF6, GH8, ______
# Expected: A
# Model Answer:
# {
#     "answer": "D",
#     "reasoning": "The pattern follows alternating letters starting from A and increasing even numbers. Each pair of letters moves two places forward in the alphabet (AB to CD, CD to EF, EF to GH). The next pair should follow GH with IJ, and the number increases by 2 from 8 to 10 but the pattern here breaks as the sequence should maintain IJ8."
# }
#
# === Question 19 ===
# Question: In a linear arrangement facing each other, five men A, B, C, D, E face five women F, G, H, I, J. A faces G, who is to the immediate left of H. C is immediately to the right of A. B is to the immediate left of D, who faces I. J is at one end. If G and H swap places, who is directly opposite the second person to the right of G?
# Expected: D
# Model Answer:
# {
#     "answer": "B",
#     "reasoning": "Initially, A faces G, with C to A's right and G to H's immediate left. B is to the immediate left of D, facing I. J is at one end. After swapping G and H, G now faces A, and H faces C. The second person to the right of G is C, so H is directly opposite C."
# }
#
# === Question 20 ===
# Question: In a circular arrangement, six friends A, B, C, D, E, and F sit around a table. A sits opposite B, C is between D and E, and F is to the immediate right of A. Who is sitting to the immediate left of D?
# Expected: A
# Model Answer:
# {
#     "answer": "B",
#     "reasoning": "Since A is opposite B, and F is to the immediate right of A, we place A and B opposite each other with F next to A. Given C is between D and E, C must be on A's left, making D and E the neighbors of C. Thus, the order around the table is A-F-B-C-D-E or its reverse. Hence, B is to the immediate left of D."
# }
#
# === Question 21 ===
# Question: Rajesh says, "He is the son of my mother's only daughter." How is Rajesh related to the boy?
# Expected: B
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "Rajesh says he is the son of his mother's only daughter. This means Rajesh's mother's only daughter is Rajesh's sister. The boy mentioned is therefore Rajesh's sister's son, making Rajesh the boy's uncle's brother or simply the boy's uncle's sibling, which is his brother."
# }
#
# === Question 22 ===
# Question: Rajesh says, "He is the son of my father's only sibling." How is Rajesh related to the person he is referring to?
# Expected: C
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "Rajesh states he is the son of his father's only sibling. This means the person he is referring to is his father’s sibling, making them cousins. Hence, the correct relation is cousin."
# }
#
# === Question 23 ===
# Question: AB2, CD4, EF6, GH8, ______
# Expected: A
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "The pattern follows consecutive pairs of letters (AB, CD, EF, GH) with increasing even numbers (2, 4, 6, 8). The next pair should be 'IJ' with the next even number, which is 10."
# }
#
# === Question 24 ===
# Question: Statement I: All books are pens; Statement II: No pen is a pencil; Statement III: Some pencils are erasers; Conclusions I: No book is a pencil; Conclusion II: Some erasers are not books
# Expected: B
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "From Statement I and II, since all books are pens and no pen is a pencil, it logically follows that no book can be a pencil. However, Statement III does not provide enough information to conclude that some erasers are not books, as there's no direct link between books and erasers."
# }
#
# === Question 25 ===
# Question: AB_1, CD_2, EF_3, GH_4, _____
# Expected: B
# Model Answer:
# {
#     "answer": "B",
#     "reasoning": "The pattern follows consecutive pairs of letters (AB, CD, EF, GH) followed by increasing numbers (1, 2, 3, 4). The next pair of letters should follow GH, which is HI. Thus, the correct sequence is HI_5."
# }
#
# === Question 26 ===
# Question: Rajesh introduces a man as his maternal uncle's son. How is the man related to Rajesh?
# Expected: C
# Model Answer:
# {
#     "answer": "D",
#     "reasoning": "Rajesh's maternal uncle is his mother's brother. Therefore, the man introduced as Rajesh’s maternal uncle's son would be Rajesh's cousin. However, the question specifies that he is the maternal uncle's son, making him the brother of Rajesh’s mother, which makes him Rajesh’s uncle. But since the question asks how the man is related to Rajesh, and given the options, the correct relation is that the man is Rajesh's nephew, as Rajesh’s maternal uncle’s son is Rajesh’s mother’s brother’s son, thus Rajesh’s nephew."
# }
#
# === Question 27 ===
# Question: Statement I: Some cats are dogs. Statement II: All dogs are mammals. Statement III: Some mammals are birds. Conclusions I: Some mammals are cats. Conclusion II: Some birds are dogs.
# Expected: C
# Model Answer:
# {
#     "answer": "D",
#     "reasoning": "Statement I implies some overlap between cats and dogs but does not confirm any mammal status for cats directly. Statement II confirms dogs are mammals, but this doesn't necessarily mean some mammals are cats. Statement III states some mammals are birds, unrelated to dogs or cats. Thus, neither conclusion logically follows."
# }
#
# === Question 28 ===
# Question: Statement I: All cats are mammals. Statement II: Some mammals are dogs. Statement III: No dog is a cat. Conclusions I: Some dogs are mammals. Conclusion II: No mammal is a cat.
# Expected: C
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "Statement I confirms all cats are mammals, making it true that some dogs (being mammals) are indeed mammals. However, Statement II does not imply no mammal is a cat; it only states some mammals are dogs. Therefore, only Conclusion I logically follows."
# }
#
# === Question 29 ===
# Question: AB_2, CD_4, EF_6, GH_8, ______
# Expected: C
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "The pattern follows alphabetical order with consecutive letters for the first two characters and increments by 2 for the number. Thus, after GH_8, the next pair should be IJ followed by 10."
# }
#
# === Question 30 ===
# Question: Statement I: Some dogs are cats Statement II: All cats are birds Statement III: Some birds are fish Conclusions I: Some fish are cats Conclusion II: Some birds are dogs
# Expected: D
# Model Answer:
# {
#     "answer": "D",
#     "reasoning": "From Statement I: Some dogs are cats, it does not imply any direct relation between fish and cats or between birds and dogs. From Statement II: All cats are birds, this confirms some cats are indeed birds but does not establish a direct link to fish or dogs through these statements. Statement III: Some birds are fish, does not support a direct link to cats or dogs. Therefore, neither Conclusion I nor Conclusion II can be logically derived."
# }
#
# === Question 31 ===
# Question: Statement I: All dogs are mammals. Statement II: Some mammals are pets. Conclusion I: Some pets are dogs. Conclusion II: Some dogs are pets.
# Expected: B
# Model Answer:
# {
#     "answer": "B",
#     "reasoning": "Statement I indicates all dogs are mammals. Statement II states some mammals are pets. From these, we cannot infer that some pets are dogs (Conclusion I), but we can infer that some dogs could be pets (Conclusion II). Therefore, only Conclusion II logically follows."
# }
#
# === Question 32 ===
# Question: Rahul says, “He is the son of my mother’s only sibling.” How is the boy related to Rahul?
# Expected: A
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "Rahul's mother has only one sibling, meaning this person is Rahul's aunt or uncle. The boy is described as the son of Rahul's mother's only sibling, making him Rahul's cousin. Therefore, the correct relation is 'Cousin'."
# }
#
# === Question 33 ===
# Question: Rajesh introduces his friend by saying, "This is my uncle's son's daughter." How is Rajesh related to the girl?
# Expected: D
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "Rajesh says 'this is my uncle's son's daughter.' Since Rajesh's uncle's son would be Rajesh's cousin, and Rajesh's cousin's daughter would make Rajesh the sister of this girl. Therefore, the girl is Rajesh's niece."
# }
#
# === Question 34 ===
# Question: AB2, CD4, EF6, GH8, ____
# Expected: A
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "The pattern follows consecutive letters in the alphabet with increasing even numbers. The sequence starts with 'AB2', 'CD4', 'EF6', 'GH8'. Following this, the next pair should be 'IJ' with the next even number, which is 10. Hence, the correct option is 'IJ10'."
# }
#
# === Question 35 ===
# Question: AB2, CD4, EF6, GH8, ______
# Expected: B
# Model Answer:
# {
#     "answer": "B",
#     "reasoning": "The pattern follows an alphabetical sequence with increasing even numbers. Each pair of letters progresses by two positions alphabetically (A to C to E to G), and the number increases by 2 (2 to 4 to 6 to 8). Thus, the next pair should be 'IJ' followed by '10'. Hence, option B is correct."
# }
#
# === Question 36 ===
# Question: AB2, CD4, EF6, GH8, _____
# Expected: A
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "The pattern follows consecutive pairs of letters where the first two letters are in alphabetical order and the number doubles each time. After GH8, the next pair should be KL8 since K comes after G and L comes after H, maintaining the sequence. The number remains 8 because it doesn't follow a doubling pattern but stays consistent."
# }
#
# === Question 37 ===
# Question: Rahul says, "He is the brother of my father's only daughter." How is the man related to Rahul?
# Expected: B
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "Rahul's father's only daughter is Rahul's sister. The man claims to be the brother of Rahul's sister, making him Rahul's uncle."
# }
#
# === Question 38 ===
# Question: Statement I: All cats are mammals Statement II: Some mammals are dogs Statement III: No dog is a cat Conclusions I: Some mammals are not cats Conclusion II: All cats are dogs
# Expected: A
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "From Statement I, we know all cats are mammals. From Statement II, some mammals are dogs but does not imply any relationship between cats and dogs. Statement III explicitly states no dog is a cat. Therefore, Conclusion I (some mammals are not cats) logically follows since there are mammals (dogs) which are not cats. Conclusion II (all cats are dogs) contradicts Statement III and hence does not follow."
# }
#
# === Question 39 ===
# Question: AB2, CD4, EF6, GH8, ______
# Expected: B
# Model Answer:
# {
#     "answer": "B",
#     "reasoning": "The pattern follows consecutive pairs of letters (AB, CD, EF, GH) and numbers increasing by 2 (2, 4, 6, 8). The next pair of letters should be IJ, and the number should follow 8 with an increment of 2, making it 10. Hence, the correct sequence is IJ10."
# }
#
# === Question 40 ===
# Question: Raj points to a man and says, "He is the brother of my father's only daughter." How is the man related to Raj?
# Expected: A
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "Raj's father's only daughter is Raj's sister. Therefore, the man Raj is pointing to is his sister's husband, making him Raj's uncle."
# }
#
# === Question 41 ===
# Question: AB2, CD4, EF6, GH8, _____
# Expected: A
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "The pattern follows consecutive letters in the alphabet with increasing even numbers. AB2, CD4, EF6, GH8, next should be IJ8 since I comes after H and the number continues the even sequence."
# }
#
# === Question 42 ===
# Question: Rajesh introduces his friend saying, “This is the son of my father’s only sibling.” How is Rajesh’s friend related to Rajesh?
# Expected: C
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "Rajesh's father has only one sibling, which means the person he is introducing is the child of this sibling. Therefore, Rajesh's friend is the child of his uncle/aunt, making him/her Rajesh's cousin."
# }
#
# === Question 43 ===
# Question: Statement I: All dogs are animals. Statement II: Some animals are cats. Statement III: No cat is a bird. Conclusions I: Some birds are animals. Conclusion II: Some animals are dogs.
# Expected: A
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "From Statement I, we know all dogs are animals, which supports Conclusion II. However, Statements I, II, and III do not provide information to conclude that some birds are animals (Conclusion I). Therefore, only Conclusion II logically follows."
# }
#
# === Question 44 ===
# Question: Statement I: All dogs are mammals. Statement II: Some mammals are cats. Conclusion I: Some cats are dogs. Conclusion II: Some mammals are dogs.
# Expected: B
# Model Answer:
# {
#     "answer": "B",
#     "reasoning": "Statement I confirms that all dogs are mammals. Statement II states some mammals are cats but does not imply any relationship between cats and dogs. Thus, Conclusion I (some cats are dogs) is invalid. However, Conclusion II logically follows since if all dogs are mammals, then some mammals must indeed be dogs."
# }
#
# === Question 45 ===
# Question: Rahul says, "He is the son of my mother's only sibling." How is the boy related to Rahul?
# Expected: B
# Model Answer:
# {
#     "answer": "B",
#     "reasoning": "Rahul states he is the son of his mother's only sibling, which means the boy's parent is Rahul's aunt or uncle. Therefore, the boy is Rahul’s cousin."
# }
#
# === Question 46 ===
# Question: Five friends A, B, C, D, and E are seated around a circular table facing outward. A is between B and C. D is to the immediate right of C. If E is not next to A, who is sitting to the immediate left of B?
# Expected: C
# Model Answer:
# {
#     "answer": "C",
#     "reasoning": "Since A is between B and C, and D is immediately to the right of C, the arrangement around the table must be B-A-C-D. Given E is not next to A, E must be to the immediate left of B. Thus, the sequence is E-B-A-C-D. Therefore, C is to the immediate left of B."
# }
#
# === Question 47 ===
# Question: Rajesh says, "He is the brother of my father's only son." How is Rajesh related to him?
# Expected: A
# Model Answer:
# {
#     "answer": "D",
#     "reasoning": "Rajesh states he is the brother of Rajesh's father's only son. Since Rajesh’s father's only son is Rajesh himself, Rajesh must be referring to his own sibling. Therefore, Rajesh is the nephew of the person he is addressing."
# }
#
# === Question 48 ===
# Question: Statement I: All dogs are animals Statement II: Some animals are birds Statement III: No bird is a fish Conclusions I: Some animals are not fish Conclusion II: Some dogs are birds
# Expected: A
# Model Answer:
# {
#     "answer": "A",
#     "reasoning": "From Statement I, all dogs are animals. From Statement II, some animals are birds. From Statement III, no bird is a fish. Conclusion I states 'Some animals are not fish', which logically follows since some animals are birds and no bird is a fish. Conclusion II states 'Some dogs are birds', which does not follow because while all dogs are animals and some animals are birds, it does not imply any dogs are birds."
# }
# BATCH - 0
# Tokens: 525, Time: 17.342 seconds
# TGPS: 30.274 seconds
# BATCH - 1
# Tokens: 555, Time: 3.577 seconds
# TGPS: 155.151 seconds
# BATCH - 2
# Tokens: 615, Time: 4.128 seconds
# TGPS: 148.970 seconds
# BATCH - 3
# Tokens: 500, Time: 3.375 seconds
# TGPS: 148.169 seconds
# BATCH - 4
# Tokens: 405, Time: 2.746 seconds
# TGPS: 147.490 seconds
# BATCH - 5
# Tokens: 680, Time: 4.537 seconds
# TGPS: 149.895 seconds
# BATCH - 6
# Tokens: 440, Time: 3.005 seconds
# TGPS: 146.411 seconds
# BATCH - 7
# Tokens: 495, Time: 3.391 seconds
# TGPS: 145.967 seconds
# BATCH - 8
# Tokens: 385, Time: 2.614 seconds
# TGPS: 147.289 seconds
# BATCH - 9
# Tokens: 309, Time: 3.220 seconds
# TGPS: 95.968 seconds
# BATCH - 10
# Tokens: 255, Time: 2.680 seconds
# TGPS: 95.160 seconds
#
# ==================================================
# Total Time: 50.614 seconds; Total Tokens: 5164; TGPS: 102.027 seconds

# %% [markdown]
# #### Basic format-checks for answers from A-agent
# Generated answers must follow the [format instructions](#format-overview). The following filter is added into the `answer_agent.py`. Similar to before, two versions are saved, `answers.json` and `filtered_answers.json`. The latter is used for evaluation.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-4B", padding_side='left')

def count_tokens_a(text: str) -> int:
    """Count the number of tokens in the text using the agent's tokenizer"""
    return len(tokenizer.encode(text, add_special_tokens=False))

def filter_answers(ans: List[str|Dict[str, str]]) -> List[Dict[str, str]]:
    r"""Filter answers to ensure they are in the correct format"""
    def basic_checks(a1: Dict[str, str])->bool:
        # check required keys
        required_keys = ['answer']
        if all((key in a1) and isinstance(a1[key], str) for key in required_keys):
            if len(a1['answer']) == 1 and (a1['answer'] not in 'ABCDabcd'):
                    return False
            check_len = count_tokens_a(a1['answer'])
            if check_len < 50:
                check_len += count_tokens_a(a1.get('reasoning', 'None'))
                if check_len < 512:
                    # check answer format - EXTRA checks
                    # if len(a1['answer']) == 1 and a1['answer'].upper() in 'ABCD':
                    return True
        return False

    filtered_answers = []
    for i, a in enumerate(ans):
        if isinstance(a, dict):
            if basic_checks(a):
                filtered_answers.append(a)
            else:
                filtered_answers.append(None)
        elif isinstance(a, str):
            # Basic checks: at least with correct JSON format
            try:
                a1 = json.loads(a)
                if basic_checks(a1):
                    filtered_answers.append(a1)
                else:
                    filtered_answers.append(None)
            except json.JSONDecodeError:
                # If JSON decoding fails, skip this answer
                print(f"Skipping invalid JSON at index {i}: {a}")
                filtered_answers.append(None)
                continue
        else:
            # If the answer is neither a dict nor a str, skip it
            print(f"Skipping unsupported type at index {i}: {type(a)}")
            filtered_answers.append(None)
    return filtered_answers

# %%
with open("outputs/answers.json", "r") as f:
    answers = json.load(f)
filtered_answers = filter_answers(answers)


print(f"Number of answers: {len(answers)}")
print(f"Number of filtered answers: {len(filtered_answers)}")

# %% [markdown]
# ## Evaluation
# <!-- 🏅  -->

# %% [markdown]
# ### Scoring Criteria
#
# <!-- 📊  -->
#
# Scores are assigned based on: out of $N$ questions from Q-agent, how many an A-agent can answer and vice-versa. *No negative marking for wrong answers.*
#
# $$\text{A-agent Score} = \dfrac{\#\ \text{of questions correctly answered with expected format}}{N}\times 100$$
# $$\text{Q-agent Score} = \dfrac{\#\ \text{of questions incorrectly answered by A-agent}}{N}\times 100$$
#
#
# $N$ denotes the number of filtered / format-correct questions. **Teams whose Q-agent fails to generate at least $50\%$ of `num_questions` (where `num_questions` ranges from $2$ to $1000+$) of the questions correctly (as per [format-checking](#format-overview)) will be automatically disqualified.**<br>
#
# In case of **TIE**, closed benchmark questions will be used to evaluate the answer agents (A-agent) and rank the teams accordingly.

# %% [markdown]
# ### Scoring Example

# %%
# calculate scores...
N = len(filtered_questions)
assert N == len(filtered_answers), "Number of questions and answers must match."
num_correct_answers = len([1 for q,a in zip(filtered_questions, filtered_answers) if a is not None and q['answer'] == a['answer']])

# Here the answer may be correct, but since q['answer'] is not an option letter is not there, we face problems
# Below shown is one way of simple string parsing
num_correct_answers = len([1 for q,a in zip(filtered_questions, filtered_answers) if a is not None and q['answer'][0] == a['answer']])

a_score = num_correct_answers*100/(N+1e-9)
q_score = (N-num_correct_answers)*100/(N+1e-9)
# Announce the scores
print(f"Number of questions: {N}")
print(f"Number of correct answers: {num_correct_answers}")
print("Scores:")
print(f"Team B: A-agent score: {a_score:.2f}")
print(f"Team A: Q-agent score: {q_score:.2f}")
print(f"Innings 1 winner: {'Team A' if q_score > a_score else 'Team B' if q_score < a_score else 'Draw'}")
